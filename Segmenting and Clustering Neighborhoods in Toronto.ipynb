# %%
import numpy as np  

import pandas as pd  
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json  

# !conda install -c conda-forge geopy --yes  
from geopy.geocoders import Nominatim  

import requests 
from pandas.io.json import json_normalize 
import matplotlib.cm as cm
import matplotlib.colors as colors
 
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes 
import folium
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     ca-certificates-2020.4.5.1 |       hecc5488_0         146 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     certifi-2020.4.5.1         |   py36h9f0ad1d_0         151 KB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
# !conda install -c anaconda beautifulsoup4
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - beautifulsoup4
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2020.4.5.1         |           py36_0         159 KB  anaconda
#     openssl-1.1.1g             |       h7b6447c_0         3.8 MB  anaconda
#     ca-certificates-2020.1.1   |                0         132 KB  anaconda
#     beautifulsoup4-4.9.0       |           py36_0         165 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         4.2 MB
#
# The following packages will be UPDATED:
#
#     beautifulsoup4:  4.7.1-py36_1                          --> 4.9.0-py36_0      anaconda
#     certifi:         2020.4.5.1-py36h9f0ad1d_0 conda-forge --> 2020.4.5.1-py36_0 anaconda
# ...

# %%
from bs4 import BeautifulSoup
import requests as rq
import pandas as pd

# %%
link = rq.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(link.text,'html.parser')

table = soup.find('table',{'class':'wikitable sortable'}).tbody 

rows = table.find_all('tr')

# define the dataframe columns
column_names = ['Postalcode', 'Borough', 'Neighborhood']

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names) 

#fill the rows

for i in range(1,len(rows)):
    data = [row.text.replace('\n','') for row in rows[i].find_all("td")]
    if(data[1] != 'Not assigned'):
         neighborhoods = neighborhoods.append({'Postalcode': data[0],
                                          'Borough': data[1],
                                          'Neighborhood': data[2]}, ignore_index=True)
            
#to sort values
neighborhoods = neighborhoods.sort_values(by='Postalcode')

# %%
for i in range(1,len(rows)):
    data = [row.text.replace('\n','') for row in rows[i].find_all("td")]
    if(data[1] != 'Not assigned'):
         neighborhoods = neighborhoods.append({'Postalcode': data[0],
                                          'Borough': data[1],
                                          'Neighborhood': data[2]}, ignore_index=True)

# %%
neighborhoods
# Out:
#     Postalcode           Borough  \
# 6          M1B       Scarborough
# 12         M1C       Scarborough
# 18         M1E       Scarborough
# 22         M1G       Scarborough
# 26         M1H       Scarborough
# 32         M1J       Scarborough
# 38         M1K       Scarborough
# 44         M1L       Scarborough
# 51         M1M       Scarborough
# 58         M1N       Scarborough
# 65         M1P       Scarborough
# 71         M1R       Scarborough
# 78         M1S       Scarborough
# 82         M1T       Scarborough
# 85         M1V       Scarborough
# 90         M1W       Scarborough
# 95         M1X       Scarborough
# 27         M2H        North York
# 33         M2J        North York
# 39         M2K        North York
# 45         M2L        North York
# 52         M2M        North York
# 59         M2N        North York
# 66         M2P        North York
# 72         M2R        North York
# 0          M3A        North York
# 7          M3B        North York
# ...

# %%
neighborhoods.shape
# Out:
# (103, 3)

# %%
location = pd.read_csv("http://cocl.us/Geospatial_data")
location = location.sort_values(by='Postal Code')

# %%
neighborhoods['Latitude'] = location['Latitude']  
neighborhoods['Longitude'] = location['Longitude']

# %%
neighborhoods
# Out:
#     Postalcode           Borough  \
# 6          M1B       Scarborough
# 12         M1C       Scarborough
# 18         M1E       Scarborough
# 22         M1G       Scarborough
# 26         M1H       Scarborough
# 32         M1J       Scarborough
# 38         M1K       Scarborough
# 44         M1L       Scarborough
# 51         M1M       Scarborough
# 58         M1N       Scarborough
# 65         M1P       Scarborough
# 71         M1R       Scarborough
# 78         M1S       Scarborough
# 82         M1T       Scarborough
# 85         M1V       Scarborough
# 90         M1W       Scarborough
# 95         M1X       Scarborough
# 27         M2H        North York
# 33         M2J        North York
# 39         M2K        North York
# 45         M2L        North York
# 52         M2M        North York
# 59         M2N        North York
# 66         M2P        North York
# 72         M2R        North York
# 0          M3A        North York
# 7          M3B        North York
# ...

# %%
for i in neighborhoods['Borough']:
    name_t = ''
    if 'Toronto' in i and i != name_t:
        Toronto_data = Toronto_data.append(neighborhoods[neighborhoods['Borough'] == i].reset_index(drop=True))
        name_t = i

# %%
Toronto_data = Toronto_data.drop_duplicates(subset=['Postalcode']).reset_index()

# %%
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

kclusters = 5
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi in zip(Toronto_data['Latitude'], Toronto_data['Longitude'], Toronto_data['Neighborhood']):
    label = folium.Popup(' Cluster ' + str(poi), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[4],
        fill=True,
        fill_color=rainbow[4],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
